# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def quickSort(self, arr, low, high):
        #code here 
        
        # Base Condition
        if low == high:
            return 
        
        if low < high:
            ind = self.partition(arr, low, high)
            self.quickSort(arr, low, ind - 1)
            self.quickSort(arr, ind + 1, high)

    def partition(self, arr, low, high):
        #code here
        
        i, j = low, low
        
        pivot = high
        
        while j < pivot:
            if arr[j] <= arr[pivot]:
                arr[i], arr[j] = arr[j], arr[i]
            
                i += 1
                j += 1
            else:
                j += 1
            # print(arr)
            # print(i, j)
            
        arr[i], arr[pivot] = arr[pivot], arr[i]
        
        # print(i)
        # print(pivot)
                
        return i

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from collections import deque

# A binary tree Node
# class Node:
#     def __init__(self, val):
#         self.data = val
#         self.left = None
#         self.right = None

class Solution:
    def levelOrder(self, root):
        # code here
        
        if root is None:
            return []
            
        ans = []
        
        q = deque()
        
        q.append(root)
        
        node = 0
                
        while len(q) != 0:
            node = q.popleft()
            
            # 1. Add the VALUE to the answer list
            ans.append(node.data)
            
            # 2. Add the CHILD NODE OBJECTS to the queue (NOT to ans)
            if node.left is not None:
                q.append(node.left)  # Keep the object!
            
            if node.right is not None:
                q.append(node.right) # Keep the object!
                
        return ans

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

from collections import deque

class Solution(object):
    def averageOfLevels(self, root):
        """
        :type root: Optional[TreeNode]
        :rtype: List[float]
        """
        q = deque()

        q.append(root)

        # level = 0

        size = 1

        ans = []

        while len(q) != 0:
            print(size)
            average = []

            while size > 0:

                node = q.popleft()

                if node.left != None:
                    q.append(node.left)
                if node.right != None:
                    q.append(node.right)

                average.append(node.val)

                size -= 1
                # level += 1

            ans.append(float(sum(average))/float(len(average)))

            size = len(q)

            print(average)

        return ans
# Out:
# 3

# %% [markdown]
# HomeWork Problem
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# Definition for a binary tree node.
# class TreeNode(object):
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right

from collections import deque

class Solution(object):
    def levelOrderBottom(self, root):
        """
        :type root: Optional[TreeNode]
        :rtype: List[List[int]]
        """
        if not root:
            return []
        
        result = []
        queue = deque([root])
        
        
        while queue:
            level_size = len(queue)
            level = []
            for _ in range(level_size):
                node = queue.popleft()
                level.append(node.val)
                if node.left:
                    queue.append(node.left)
                if node.right:
                    queue.append(node.right)
            result.append(level)
        
        # Reverse to get bottom-up order
        return result[::-1]

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
'''
Definition for Node
class Node:
    def _init_(self, val):
        self.data = val
        self.left = None
        self.right = None
'''
# Height using Inorder Traversal
class Solution:
    def height(self, root):
        # code here
        
        # print(root.data)
        
        if root is None:
            return -1
            
        lsh = self.height(root.left)
        rsh = self.height(root.right)
        
        return 1 + max(lsh, rsh)

# %%
# Height using Level order traversal 
'''
Definition for Node
class Node:
    def _init_(self, val):
        self.data = val
        self.left = None
        self.right = None
'''
from collections import deque
class Solution:
    def height(self, root):
        # code here
        
        q = deque()

        q.append(root)

        level = -1

        size = 1

        while len(q) != 0:
            # print(size)
            

            while size > 0:

                node = q.popleft()

                if node.left != None:
                    q.append(node.left)
                if node.right != None:
                    q.append(node.right)

                size -= 1
            level += 1

            size = len(q)


        return level
