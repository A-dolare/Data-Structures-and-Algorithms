# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from collections import deque
class Solution:
    def nextLargerElement(self, arr):
        n = len(arr)
        q = deque()
        ans = []
        
        for i in range(n - 1, -1, -1):
            while q and q[-1] <= arr[i]:
                q.pop()
                
            if not q:
                ans.append(-1)
            else:
                ans.append(q[-1])
            q.append(arr[i])
            
        return ans[::-1]

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from collections import deque
class Solution:
	def preGreaterEle(self, arr):
		# code here
		q = deque()
		ans = []
		
		for num in arr:
		    while q and q[-1] <= num:
		        q.pop()
		    
		    if q:
		        ans.append(q[-1])
		    else:
		        ans.append(-1)
		  
		    q.append(num)
		    
	    return ans

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from collections import deque
class Solution:
	def nextSmallerEle(self, arr):
		# code here
		n = len(arr)
		q = deque()
		ans = []
		
		for i in range(n - 1, -1, -1):
		    while q and q[-1] >= arr[i]:
		        q.pop()
		        
		    if q:
		        ans.append(q[-1])
		    else:
		        ans.append(-1)
		        
		    q.append(arr[i])
		    
	    return ans[::-1]

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from collections import deque
class Solution:
	def prevSmaller(self, arr):
		# code here
		n = len(arr)
		stack = deque()
		ans = []
		
		for num in arr:
		    while stack and stack[-1] >= num:
		        stack.pop()
		        
		    if stack:
		        ans.append(stack[-1])
		    else:
		        ans.append(-1)
		        
		    stack.append(num)
		    
	    return ans

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from collections import deque
class Solution:
    def dailyTemperatures(self, temperatures: List[int]) -> List[int]:
        stack = deque()
        ans = []
        n = len(temperatures)

        for i in range(n - 1, -1, -1):
            while stack and temperatures[stack[-1]] <= temperatures[i]:
                stack.pop()

            if stack:
                # subtracted 'i' to find the number of days for next horter day
                ans.append(stack[-1] - i)
            else:
                ans.append(0)

            stack.append(i)

        return ans[::-1]

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
class StockSpanner:

    def __init__(self):
        self.stack = []
        

    def next(self, price: int) -> int:
        span = 1
        
        while self.stack and self.stack[-1][0] <= price:
            prev, prev_span = self.stack.pop()
            span += prev_span

        self.stack.append([price, span])

        return span

# Your StockSpanner object will be instantiated and called as such:
# obj = StockSpanner()
# param_1 = obj.next(price)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# from collections import deque
class Solution:
    def largestRectangleArea(self, heights: List[int]) -> int:

        n = len(heights)

        # if n == 1:
        #     return heights[0]

        stack = []
        nse = []
        pse = []
        ans = 0

        # finding previous smaller element
        for i in range(n):
            while stack and heights[stack[-1]] >= heights[i]:
                stack.pop()
            if stack:
                pse.append(stack[-1])
            else:
                pse.append(-1)

            stack.append(i)

        stack.clear()

        # finding next smaller element
        for i in range(n - 1, -1, -1):
            while stack and heights[stack[-1]] >= heights[i]:
                stack.pop()
            if stack:
                nse.append(stack[-1])
            else:
                nse.append(n)

            stack.append(i)

        # print(pse, nse[::-1])
        nse = nse[::-1]

        for i in range(n):
            ans = max(ans, heights[i] * (nse[i] - pse[i] - 1))

        return ans
