# %% [markdown]
# | Step | Current Prime ($p$) | Action (Mark Multiples) | `is_prime` Array State (Indices 0 to 4) | Primes Found So Far |
# | :--- | :---: | :--- | :--- | :--- |
# | **Init** | - | Initialize all to `True` (except 0, 1) | `[F, F, T, T, T]` | `[]` |
# | **Loop 1** | $p = 2$ | Mark multiples of 2 ($4$) as `False` | `[F, F, T, T, F]` | `[2]` |
# | **Loop 2** | $p = 3$ | $3^2 = 9 > 4$, loop ends | `[F, F, T, T, F]` | `[2, 3]` |
# | **Result** | - | Collect indices where `True` | - | **`[2, 3]`** |
#
#
# | Prime ($p$) | Calculation of Exponent ($\sum \lfloor \frac{N}{p^k} \rfloor$) | Terms Summed | Final Exponent ($E_p$) | Term Contribution ($E_p + 1$) | Running Total |
# | :---: | :--- | :--- | :---: | :---: | :---: |
# | **2** | $\lfloor \frac{4}{2} \rfloor + \lfloor \frac{4}{4} \rfloor$ | $2 + 1$ | **3** | $3 + 1 = \mathbf{4}$ | $1 \times 4 = \mathbf{4}$ |
# | **3** | $\lfloor \frac{4}{3} \rfloor$ | $1$ | **1** | $1 + 1 = \mathbf{2}$ | $4 \times 2 = \mathbf{8}$ |
